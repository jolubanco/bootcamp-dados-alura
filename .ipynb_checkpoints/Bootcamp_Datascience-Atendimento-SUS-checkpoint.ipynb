# %% [markdown]
# ## Caderno de exploração dos dados do DataSUS de 2008 até 2021 correspondente ao Valor total por Ano/mês atendimento segundo Unidade da Federação

# %%
import pandas as pd

# %%
#Os dados não utilazam o padrão UTF-8 de acentuação, assim precisamos modicar a base dados, além disso os dados possuem
#3 linhas e 12 colunas de dados 'lixo', não trazem nenhum informação, e por fim precisamos formatar como os dados serão
#apresentados utilizando o padrão americano de casas decimais e pontuação de milhares

dados = pd.read_csv("dados/base_de_dados_SUS_atendimento.csv", sep =";", encoding="ISO-8859-1",
                    skiprows = 3, skipfooter = 12, thousands=".", decimal=",")
# Out:
# <ipython-input-3-829cbef3d45e>:5: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   dados = pd.read_csv("dados/base_de_dados_SUS_atendimento.csv", sep =";", encoding="ISO-8859-1",

# %%
dados.head()
# Out:
#   Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan 1994/Fev  \
# 0          11 Rondônia        -        -        -        -        -        -
# 1              12 Acre        -        -        -        -        -        -
# 2          13 Amazonas        -        -        -        -        -        -
# 3           14 Roraima        -        -        -        -        -        -
# 4              15 Pará        -        -        -        -        -        -
#
#   1994/Mai 1994/Ago 1994/Nov  ...     2020/Jul     2020/Ago     2020/Set  \
# 0        -        -        -  ...  10479989.36  11433467.56   8876900.39
# 1        -        -        -  ...   4053085.41   3658265.59   3470409.45
# 2        -        -        -  ...  19303743.16  18687233.58  18628627.49
# 3        -        -        -  ...   3192075.41   3262354.34   2978629.22
# 4        -        -        -  ...  40496349.97  38793393.54  36965951.76
#
# ...

# %%
dados
# Out:
#       Unidade da Federação  1992/Mar  1992/Abr  1993/Mai  1993/Dez  1994/Jan  \
# 0              11 Rondônia         -         -         -         -         -
# 1                  12 Acre         -         -         -         -         -
# 2              13 Amazonas         -         -         -         -         -
# 3               14 Roraima         -         -         -         -         -
# 4                  15 Pará         -         -         -         -         -
# 5                 16 Amapá         -         -         -         -         -
# 6             17 Tocantins         -         -         -         -         -
# 7              21 Maranhão         -         -         -         -         -
# 8                 22 Piauí         -         -         -         -         -
# 9                 23 Ceará         -         -         -         -         -
# 10  24 Rio Grande do Norte         -         -         -         -         -
# ...

# %%
dados.tail()
# Out:
#      Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan  \
# 22   43 Rio Grande do Sul        -        -        -        -        -
# 23  50 Mato Grosso do Sul        -        -        -        -        -
# 24         51 Mato Grosso        -        -        -        -        -
# 25               52 Goiás        -        -        -        -        -
# 26    53 Distrito Federal        -        -        -        -        -
#
#    1994/Fev 1994/Mai 1994/Ago 1994/Nov  ...      2020/Jul      2020/Ago  \
# 22        -        -        -        -  ...  1.085365e+08  1.117623e+08
# 23        -        -        -        -  ...  2.363994e+07  2.260835e+07
# 24        -        -        -        -  ...  2.068157e+07  2.093614e+07
# 25        -        -        -        -  ...  4.587133e+07  4.756816e+07
# 26        -        -        -        -  ...  2.642848e+07  2.387530e+07
#
#         2020/Set      2020/Out      2020/Nov      2020/Dez      2021/Jan  \
# ...

# %%
dados.mean()
# Out:
# 2007/Ago    3.049528e+05
# 2007/Set    7.881453e+05
# 2007/Out    2.440163e+06
# 2007/Nov    5.517354e+06
# 2007/Dez    1.233716e+07
#                 ...
# 2020/Dez    5.377291e+07
# 2021/Jan    4.947411e+07
# 2021/Fev    3.899242e+07
# 2021/Mar    2.416371e+07
# Total       6.388206e+09
# Length: 165, dtype: float64

# %%
#Mudando a forma de impressão dos numeros, para facilitar a visualização
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean()
# Out:
# 2007/Ago       304952.77
# 2007/Set       788145.26
# 2007/Out      2440162.96
# 2007/Nov      5517354.05
# 2007/Dez     12337159.42
#                 ...
# 2020/Dez     53772909.13
# 2021/Jan     49474107.60
# 2021/Fev     38992424.23
# 2021/Mar     24163712.88
# Total      6388205992.19
# Length: 165, dtype: float64

# %%
dados["2008/Ago"]
# Out:
# 0      2938286.29
# 1      1886871.84
# 2      8331763.97
# 3      1045291.11
# 4     23259148.28
# 5      1550340.63
# 6      5213290.38
# 7     14609872.57
# 8     10645917.52
# 9     29304821.51
# 10    10812840.19
# 11    12673774.35
# 12    31705296.79
# 13     9262767.68
# 14     4543252.50
# 15    43254543.33
# 16    80374117.08
# 17    12384068.19
# 18    42500830.29
# 19   180005050.15
# 20    56699001.13
# 21    28887854.62
# 22    56233758.74
# 23     9602843.49
# 24     8987811.95
# 25    21054991.27
# 26    11548451.89
# Name: 2008/Ago, dtype: float64

# %%
dados["2008/Ago"].mean()
# Out:
# 26641365.101481482

# %%
#Forma de plotar os dados utilizando o pandas
dados.plot(x ="Unidade da Federação", y ="2008/Ago", kind="bar", figsize=(9,6))
# Out:
# <AxesSubplot:xlabel='Unidade da Federação'>

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
#utilizando o Matplotlib para ajustar alguns detalhes do plot
#padrão abreviar o gráfico para 'ax'

ax = dados.plot(x ="Unidade da Federação", y ="2008/Ago", kind="bar", figsize=(13,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
#formatando os valores do eixo y para ponto flutuante, com duas casas decimais e ',' como separador de milhar (padrao americano)
plt.title("Valor gasto com o SUS, em Agosto de 2008, por unidade federativa")
plt.show()

# %%
#Gráfico utilizando mês mas recente disponível
ax = dados.plot(x="Unidade da Federação", y = "2021/Mar", kind = "bar", figsize=(13,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}"))
plt.title("Valor gasto com o SUS, em Março de 2021, por unidade federativa")
plt.show()

# %%
dados[["2008/Ago","2008/Set"]].head()
# Out:
#      2008/Ago    2008/Set
# 0  2938286.29  2843930.91
# 1  1886871.84  2084884.80
# 2  8331763.97  8148089.92
# 3  1045291.11  1003740.89
# 4 23259148.28 23667690.01

# %%
dados.describe() #Só busca os meses em que possuem dados em todos os estados
# Out:
#         2007/Ago   2007/Set    2007/Out    2007/Nov    2007/Dez      2008/Jan  \
# count      27.00      27.00       27.00       27.00       27.00         27.00
# mean   304952.77  788145.26  2440162.96  5517354.05 12337159.42   76343108.00
# std    392806.00 1071747.56  3421972.10  7767711.29 16345863.65  201153948.03
# min      4113.76   11858.63    43852.67   226661.18   470676.43     808448.39
# 25%     46580.42  139423.94   505778.42  1410610.81  3650090.00    8257222.37
# 50%    179395.82  418053.58  1152115.25  2406035.32  5949408.99   16568724.64
# 75%    392985.52  969999.75  2625635.63  5915821.61 13394973.35   52147797.62
# max   1665349.90 4434168.64 14577395.84 35032259.98 76668547.41 1038067423.15
#
#           2008/Fev     2008/Mar     2008/Abr     2008/Mai  ...     2020/Jul  \
# count        27.00        27.00        27.00        27.00  ...        27.00
# mean   23821310.52  25879711.67  26213027.10  26218488.77  ...  57693175.63
# ...

# %%
#index é uma série imutável, logo precisamos de uma lista do python que é mutável e podemos inserir dados
colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0,"Unidade da Federação") #insere na posição 0 da minha lista
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2007/Ago',
#  '2007/Set',
#  '2007/Out',
#  '2007/Nov',
#  '2007/Dez',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Set',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
# ...

# %%
usaveis = dados[colunas_usaveis]
usaveis.head()
# Out:
#   Unidade da Federação  2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# 0          11 Rondônia   4209.37  16397.03  133645.19  346912.84   711758.31
# 1              12 Acre  10470.07  14001.71   86200.85  301323.68   769612.36
# 2          13 Amazonas  35752.72  45570.64  416012.30 2020381.79  5949408.99
# 3           14 Roraima   4785.91  11858.63   43852.67  369328.51   470676.43
# 4              15 Pará 181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#      2008/Jan    2008/Fev    2008/Mar    2008/Abr  ...    2020/Jul  \
# 0  1829559.71  1940792.63  1955721.68  2143353.81  ... 10479989.36
# 1  1731744.62  1743978.66  2057439.02  2057829.69  ...  4053085.41
# 2 11419210.08  7934652.10  8641517.13  8531576.49  ... 19303743.16
# 3   808448.39   771687.83   876091.18   896952.53  ...  3192075.41
# 4 21762104.16 20126081.01 22149375.82 23436682.75  ... 40496349.97
#
#      2020/Ago    2020/Set    2020/Out    2020/Nov    2020/Dez    2021/Jan  \
# ...

# %%
usaveis = usaveis.set_index("Unidade da Federação")
usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
usaveis.loc["12 Acre"] #linha cuja o indice é acre
# Out:
# 2007/Ago       10470.07
# 2007/Set       14001.71
# 2007/Out       86200.85
# 2007/Nov      301323.68
# 2007/Dez      769612.36
#                ...
# 2020/Dez     3711660.71
# 2021/Jan     3005561.16
# 2021/Fev     2272733.90
# 2021/Mar     1137341.65
# Total      450048530.47
# Name: 12 Acre, Length: 165, dtype: float64

# %%
usaveis.T.head()
# Out:
# Unidade da Federação  11 Rondônia   12 Acre  13 Amazonas  14 Roraima  \
# 2007/Ago                  4209.37  10470.07     35752.72     4785.91
# 2007/Set                 16397.03  14001.71     45570.64    11858.63
# 2007/Out                133645.19  86200.85    416012.30    43852.67
# 2007/Nov                346912.84 301323.68   2020381.79   369328.51
# 2007/Dez                711758.31 769612.36   5949408.99   470676.43
#
# Unidade da Federação     15 Pará  16 Amapá  17 Tocantins  21 Maranhão  \
# 2007/Ago               181159.29  33672.74       4113.76    385330.18
# 2007/Set               433414.74 104822.98      76633.06   1018352.93
# 2007/Out              1893197.50 118378.28     343702.61   2277717.78
# 2007/Nov              5105406.44 226661.18    1068685.94   4334468.23
# 2007/Dez             13162823.43 844019.90    3022200.87   8832514.85
#
# Unidade da Federação   22 Piauí    23 Ceará  ...  32 Espírito Santo  \
# ...

# %%
usaveis.T.plot(figsize=(12,6))
# Out:
# <AxesSubplot:>

# %%
usaveis = usaveis.drop("Total", axis = 1)
usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
usaveis.T.plot(figsize=(15,6))
# Out:
# <AxesSubplot:>

# %%
#plotar utilizando estados aleatórios
#setando a semente (seed) para obter os mesmos resultados, utilizando o numpy
import numpy as np
np.random.seed(687942)
usaveis.sample(5).T.plot(figsize=(12,6))
# Out:
# <AxesSubplot:>

# %%
#Adicionando uma coluna nova
usaveis["Total"] = usaveis.sum(axis=1)
usaveis.head()
# Out:
#                       2007/Ago  2007/Set   2007/Out   2007/Nov    2007/Dez  \
# Unidade da Federação
# 11 Rondônia            4209.37  16397.03  133645.19  346912.84   711758.31
# 12 Acre               10470.07  14001.71   86200.85  301323.68   769612.36
# 13 Amazonas           35752.72  45570.64  416012.30 2020381.79  5949408.99
# 14 Roraima             4785.91  11858.63   43852.67  369328.51   470676.43
# 15 Pará              181159.29 433414.74 1893197.50 5105406.44 13162823.43
#
#                         2008/Jan    2008/Fev    2008/Mar    2008/Abr  \
# Unidade da Federação
# 11 Rondônia           1829559.71  1940792.63  1955721.68  2143353.81
# 12 Acre               1731744.62  1743978.66  2057439.02  2057829.69
# 13 Amazonas          11419210.08  7934652.10  8641517.13  8531576.49
# 14 Roraima             808448.39   771687.83   876091.18   896952.53
# 15 Pará              21762104.16 20126081.01 22149375.82 23436682.75
#
# ...

# %%
ordenado_por_total = usaveis.sort_values("Total", ascending=False).head()
ordenado_por_total = ordenado_por_total.drop("Total",axis=1)
ordenado_por_total.head()
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 35 São Paulo         1665349.90 4434168.64 14577395.84 35032259.98
# 31 Minas Gerais       971394.37 2861781.50 10018011.35 21730281.63
# 41 Paraná             554800.22 1431708.01  4630402.44 11120030.79
# 43 Rio Grande do Sul 1049252.33 3182913.14  8571312.11 16592432.80
# 33 Rio de Janeiro     469469.34  921646.57  2994664.57  7250528.08
#
#                         2007/Dez      2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 35 São Paulo         76668547.41 1038067423.15 172961999.58 170556696.16
# 31 Minas Gerais      43429517.54  206208080.90  70301089.50  79119005.51
# 41 Paraná            28790722.87   58081334.45  48855046.46  55611791.07
# 43 Rio Grande do Sul 30134255.70   51064610.03  45897704.82  52928695.92
# 33 Rio de Janeiro    13627123.27  251511992.03  44128159.73  42900847.02
#
# ...

# %%
ordenado_por_total.head(5).T.plot(figsize=(12,6))
# Out:
# <AxesSubplot:>

# %%
colunas_interessadas = ordenado_por_total.columns[6:]
ordenado_por_total = ordenado_por_total[colunas_interessadas]

# %%
ordenado_por_total.head(5).T.plot(figsize=(12,6))
# Out:
# <AxesSubplot:>

# %%
ordenado_por_total = ordenado_por_total / 1000000
ordenado_por_total.head(5).T.plot(figsize=(12,6))
# Out:
# <AxesSubplot:>

# %%
#cuidados na hora de recortar informações do data frame, pode gerar distorções
meses_filtrados = ordenado_por_total.columns[47:150]
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(12,6))
# Out:
# <AxesSubplot:>

# %%
ordenado_por_total[meses_filtrados].head(3).T.plot(figsize=(12,6))
plt.ylim(0,350)
# Out:
# (0.0, 350.0)

# %%
ordenado_por_total[ordenado_por_total.columns[-12:]].head(3).T.plot(figsize=(12,6))
plt.ylim(0,500)
# Out:
# (0.0, 500.0)

# %%
#manipulando a informação atraves da escala do grafico
ordenado_por_total.head(5).T.plot(figsize=(6,6))
# Out:
# <AxesSubplot:>

# %%
ordenado_por_total.head(5).T.plot(figsize=(20,6))
# Out:
# <AxesSubplot:>

# %%
mes_mais_recente = ordenado_por_total.columns[-1]
mes_mais_recente
# Out:
# '2021/Mar'

# %%
gastos_do_mais_recente = ordenado_por_total[mes_mais_recente]
gastos_do_mais_recente
# Out:
# Unidade da Federação
# 35 São Paulo           177.41
# 31 Minas Gerais         79.78
# 41 Paraná               43.48
# 43 Rio Grande do Sul    37.80
# 33 Rio de Janeiro       49.15
# Name: 2021/Mar, dtype: float64

# %%
gastos_do_mais_recente.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='2021/Mar'>

# %%
gastos_do_mais_recente
# Out:
# Unidade da Federação
# 35 São Paulo           177.41
# 31 Minas Gerais         79.78
# 41 Paraná               43.48
# 43 Rio Grande do Sul    37.80
# 33 Rio de Janeiro       49.15
# Name: 2021/Mar, dtype: float64

# %%
gastos_do_mais_recente / gastos_do_mais_recente.loc["35 São Paulo"]
# Out:
# Unidade da Federação
# 35 São Paulo           1.00
# 31 Minas Gerais        0.45
# 41 Paraná              0.25
# 43 Rio Grande do Sul   0.21
# 33 Rio de Janeiro      0.28
# Name: 2021/Mar, dtype: float64

# %%
gastos_do_mais_recente = gastos_do_mais_recente.sort_values(ascending=False)
gastos_do_mais_recente.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Unidade da Federação'>

# %% [markdown]
# # Desafio 01: Reposicionar a legenda. Dentro? Fora? Onde?

# %% [markdown]
# # Desafio 02: Plotar o gráfico de linha com apenas 5 estados de sua preferência

# %%
desafio_5_estados = usaveis.T[["41 Paraná","42 Santa Catarina","43 Rio Grande do Sul","11 Rondônia","33 Rio de Janeiro"]].plot(figsize=(15,6))
desafio_5_estados

# %% [markdown]
# # Desafio 03: Mudar a pallete de cores com matplotlib

# %% [markdown]
# # Desafio 04: Adicionar uma coluna mostrando a região de cada estado

# %% [markdown]
# # Desafio 05: Deixar o gráfico mais bonito. A mensagem mais clara

# %% [markdown]
# # Desafio 06: Adicione seu estado aos 5 estados existente e plote

# %% [markdown]
# # Desafio 07: Plotar só os estados do sudeste e ver se afetou com um pico em 2012/2013 de forma similar nesse estados

# %% [markdown]
# # Desafio 08: Adicionar seu estado novamente e deixe o gráfico informativo com suas informações

# %% [markdown]
# # Desafio 09: Refaça as manipulações feitas em aulas e gaste um tempo analisando os dados e entendendo os efeitos das manipulações

# %% [markdown]
# # Desafio 10: Reflita sobre os problemas na manipulação de dados e discuta esse assunto no Discord.

# %% [markdown]
# # Desafio 11: Criar a tabela de comparação do seu estado, relativo a proporção dos gastos

# %% [markdown]
# # Desafio 12: Colocar grid no gráfico para se localizar melhor

# %% [markdown]
# # Desafio 13: Fazer um gráfico e uma tabela do gasto dos outros estados em função do seu estado, ou qualquer outro de interesse.

# %% [markdown]
# # Desafio 14: Fazer o cálculo proporcional a população do seu estado e mais um a sua escolha.

# %% [markdown]
# # Desafio 15: Faça uma análise dos dados analisados, levante hipóteses e compartilhe com a gente no Discord.

# %% [markdown]
# # Desafio 16: Reproduza as análises feitas em aulas, refletindo e levantando hipóteses.

# %% [markdown]
# # Super Desafio: Escolha outro valor fora o valor aprovado no TABNET e explore estes dados. Esse será nosso projeto do módulo, mais detalhes no Desafio do módulo 1 na página do bootcamp.
